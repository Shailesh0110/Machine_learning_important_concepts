# %%
import pandas as pd
import requests

# %%
responce=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=6fc2568430534f955e30ef080f86250f&language=en-US&page=1")

# %%
df=pd.DataFrame(responce.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df
# Out:
#         id                           title  \
# 0   851644               20th Century Girl
# 1      238                   The Godfather
# 2      278        The Shawshank Redemption
# 3   620249               The Legend of Hei
# 4      240           The Godfather Part II
# 5      424                Schindler's List
# 6    19404     Dilwale Dulhania Le Jayenge
# 7   667257               Impossible Things
# 8      129                   Spirited Away
# 9      389                    12 Angry Men
# 10  372058                      Your Name.
# 11  372754        Dou kyu sei – Classmates
# 12  496243                        Parasite
# 13     497                  The Green Mile
# 14  724089      Gabriel's Inferno: Part II
# 15     155                 The Dark Knight
# 16  696374               Gabriel's Inferno
# 17  553512       Burn the Stage: The Movie
# 18     680                    Pulp Fiction
# 19     429  The Good, the Bad and the Ugly
#
# ...

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,526):
    responce=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=6fc2568430534f955e30ef080f86250f&language=en-US&page={}".format(i))
    temp_df=pd.DataFrame(responce.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]  
    df=df.append(temp_df,ignore_index=True)
# Out:
# C:\Users\Shailesh\AppData\Local\Temp\ipykernel_6916\1753765846.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\Shailesh\AppData\Local\Temp\ipykernel_6916\1753765846.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\Shailesh\AppData\Local\Temp\ipykernel_6916\1753765846.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\Shailesh\AppData\Local\Temp\ipykernel_6916\1753765846.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# ...

# %%
df
# Out:
#           id                           title  \
# 0     851644               20th Century Girl
# 1        238                   The Godfather
# 2        278        The Shawshank Redemption
# 3     620249               The Legend of Hei
# 4        240           The Godfather Part II
# ...      ...                             ...
# 9995  271404                  Beyond Skyline
# 9996  122081                 Spring Breakers
# 9997   11453  Deuce Bigalow: European Gigolo
# 9998  243938          Hot Tub Time Machine 2
# 9999    9053              DOA: Dead or Alive
#
#                                                overview release_date  \
# 0     Yeon-du asks her best friend Bora to collect a...   2022-10-06
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     Framed in the 1940s for the double murder of h...   1994-09-23
# 3     In the bustling human world, spirits live peac...   2019-08-27
# 4     In the continuing saga of the Corleone crime f...   1974-12-20
# ...
