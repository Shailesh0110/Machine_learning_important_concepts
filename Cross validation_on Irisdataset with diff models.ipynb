# %%
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats as stats

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest,chi2
from sklearn.tree import DecisionTreeClassifier
from sklearn import set_config
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import PowerTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import ExtraTreesClassifier
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
import statsmodels.api as sm

# %%
df= pd.read_csv("Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
X=sm.add_constant(X)

# %%
X=df.drop(columns=['Species'])
y=df['Species']

# %%
X
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
X=sm.add_constant(X)

# %%
X
# Out:
#      const   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1.0    1            5.1           3.5            1.4           0.2
# 1      1.0    2            4.9           3.0            1.4           0.2
# 2      1.0    3            4.7           3.2            1.3           0.2
# 3      1.0    4            4.6           3.1            1.5           0.2
# 4      1.0    5            5.0           3.6            1.4           0.2
# ..     ...  ...            ...           ...            ...           ...
# 145    1.0  146            6.7           3.0            5.2           2.3
# 146    1.0  147            6.3           2.5            5.0           1.9
# 147    1.0  148            6.5           3.0            5.2           2.0
# 148    1.0  149            6.2           3.4            5.4           2.3
# 149    1.0  150            5.9           3.0            5.1           1.8
#
# [150 rows x 6 columns]

# %%
model=sm.OLS(y,X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         Species_encode   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     654.2
# Date:                Wed, 23 Nov 2022   Prob (F-statistic):           4.39e-97
# Time:                        17:28:01   Log-Likelihood:                 55.032
# No. Observations:                 150   AIC:                            -98.06
# Df Residuals:                     144   BIC:                            -80.00
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
X.iloc[ : ,1:].corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
df["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
lbe_encode=preprocessing.LabelEncoder()

# %%
df['Species_encode']=lbe_encode.fit_transform(df['Species'])

# %%
df["Species_encode"].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: Species_encode, dtype: int64

# %%
df["Species_encode"].unique()
# Out:
# array([0, 1, 2])

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  Species_encode
# 0       Iris-setosa               0
# 1       Iris-setosa               0
# 2       Iris-setosa               0
# ...

# %%
df.drop(columns=['Species'],inplace=True)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#      Species_encode
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# ...

# %%
X=df.drop(columns=['Species_encode'])
y=df['Species_encode']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25)

# %%
X_train
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 119  120            6.0           2.2            5.0           1.5
# 32    33            5.2           4.1            1.5           0.1
# 142  143            5.8           2.7            5.1           1.9
# 65    66            6.7           3.1            4.4           1.4
# 77    78            6.7           3.0            5.0           1.7
# ..   ...            ...           ...            ...           ...
# 44    45            5.1           3.8            1.9           0.4
# 81    82            5.5           2.4            3.7           1.0
# 114  115            5.8           2.8            5.1           2.4
# 58    59            6.6           2.9            4.6           1.3
# 72    73            6.3           2.5            4.9           1.5
#
# [112 rows x 5 columns]

# %%
mode1=LogisticRegression()
model2=DecisionTreeClassifier()
model3=KNeighborsClassifier(n_neighbors=10)
model4=RandomForestClassifier(n_estimators=100)

# %%
score=cross_val_score(mode1,X,y,scoring='accuracy',cv=10)
score.mean()
# Out:
# C:\Users\Shailesh\anaconda4\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Shailesh\anaconda4\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
score=cross_val_score(model2,X,y,scoring='accuracy',cv=10)
score.mean()
# Out:
# 0.9333333333333332

# %%
score=cross_val_score(model3,X,y,scoring='accuracy',cv=10)
score.mean()
# Out:
# 0.9400000000000001

# %%
score=cross_val_score(model4,X,y,scoring='accuracy',cv=10)
score.mean()
# Out:
# 0.9866666666666667
