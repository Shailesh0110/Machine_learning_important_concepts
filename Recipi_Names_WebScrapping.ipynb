# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0'
}
webpage=requests.get("https://www.chopchopfamily.org/recipes/?pg=2",headers=headers).text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-CA">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, user-scalable=yes" name="viewport"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <link href="styles.css" media="screen,projection,tv" rel="stylesheet"/>
#   <link href="print.css" media="print" rel="stylesheet"/>
#   <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
#   <script type="text/javascript">
#    var epic_ajax_url = 'https://www.chopchopfamily.org/?epic-ajax-request=epic-ne';
#   </script>
#   <!-- This site is optimized with the Yoast SEO plugin v19.10 - https://yoast.com/wordpress/plugins/seo/ -->
#   <title>
#    ChopChopFamily.org - Our Recipes
#   </title>
#   <link href="https://www.chopchopfamily.org/recipes/" rel="canonical"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="article" property="og:type"/>
# ...

# %%
<div class="card__content">
			<h5>Our Favorite Applesauce</h5>
		</div>
# Out:
#   File <tokenize>:3
#     </div>
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
len(recipi_link)
# Out:
# 20

# %%
recipi_link
# Out:
# [<div class="n-grid__cell">
#  <a class="card card--recipe" href="https://www.chopchopfamily.org/recipe/easy-apple-bites/">
#  <img alt="" class="card__image" src="https://www.chopchopfamily.org/wp-content/uploads/2022/11/Easy_Apple_Bites-13.jpg"/>
#  <div class="card__content">
#  <h5>Easy Apple Bites</h5>
#  </div>
#  </a>
#  </div>,
#  <div class="n-grid__cell">
#  <a class="card card--recipe" href="https://www.chopchopfamily.org/recipe/instant-ramen-soup/">
#  <img alt="" class="card__image" src="https://www.chopchopfamily.org/wp-content/uploads/2022/11/instant_ramen-4.jpg"/>
#  <div class="card__content">
#  <h5>Instant Ramen Soup</h5>
#  </div>
#  </a>
#  </div>,
#  <div class="n-grid__cell">
#  <a class="card card--recipe" href="https://www.chopchopfamily.org/recipe/bbq-chickpeas/">
#  <img alt="" class="card__image" src="https://www.chopchopfamily.org/wp-content/uploads/2022/11/BBQ_chickpeas_14.jpg"/>
#  <div class="card__content">
#  <h5>BBQ Chickpeas</h5>
#  </div>
#  </a>
# ...

# %%
url_link=soup.find_all()

# %%
len(url_link)
# Out:
# 947

# %%
url_link=BeautifulSoup(webpage,'lxml')

# %%
url_link
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-CA">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, user-scalable=yes" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <link href="styles.css" media="screen,projection,tv" rel="stylesheet"/>
# <link href="print.css" media="print" rel="stylesheet"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
# <script type="text/javascript"> var epic_ajax_url = 'https://www.chopchopfamily.org/?epic-ajax-request=epic-ne'; </script>
# <!-- This site is optimized with the Yoast SEO plugin v19.10 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>ChopChopFamily.org - Our Recipes</title>
# <link href="https://www.chopchopfamily.org/recipes/" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="ChopChopFamily.org - Our Recipes" property="og:title"/>
# ...

# %%
url_link.find_all('h2')[0].text
# Out:
# '\n\t\t\t\t\tOUR RECIPES\t\t\t'

# %%
print(url_link.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-CA">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, user-scalable=yes" name="viewport"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <link href="styles.css" media="screen,projection,tv" rel="stylesheet"/>
#   <link href="print.css" media="print" rel="stylesheet"/>
#   <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
#   <script type="text/javascript">
#    var epic_ajax_url = 'https://www.chopchopfamily.org/?epic-ajax-request=epic-ne';
#   </script>
#   <!-- This site is optimized with the Yoast SEO plugin v19.10 - https://yoast.com/wordpress/plugins/seo/ -->
#   <title>
#    ChopChopFamily.org - Our Recipes
#   </title>
#   <link href="https://www.chopchopfamily.org/recipes/" rel="canonical"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="article" property="og:type"/>
# ...

# %%
url_link.find_all('meta content')
# Out:
# []

# %%
name
# Out:
# []

# %%
<div class="n-grid__cell">
	<a href="https://www.chopchopfamily.org/recipe/crazy-good-buttermilk-biscuits/" class="card card--recipe">
		<img src="https://www.chopchopfamily.org/wp-content/uploads/2018/12/chopchop_biscuits_lifestyle.jpg" class="card__image" alt="">
		<div class="card__content">
			<h5>Crazy-Good Buttermilk Biscuits</h5>
		</div>
	</a>
</div>

# %%
final=pd.DataFrame()
for j in range(1,30):
    url="https://www.chopchopfamily.org/recipes/?pg={}".format(j)
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0'}           
    webpage=requests.get(url,headers=headers).text
    soup=BeautifulSoup(webpage,'lxml')
    
    link=[]
    name=[]

    for i in recipi_name:
        link.append(i.find('n-grid_cell').text.strip())
        name.append(i.find('h5').text.strip())

    d={'nameof receipi':name}
    df=pd.DataFrame(d)
    final=final.append(df,ignore_index=True)
# Out:
# C:\Users\Shailesh\AppData\Local\Temp\ipykernel_9312\2979964005.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df,ignore_index=True)

# %%
final
# Out:
#                      nameof receipi
# 0               Summery Grain Salad
# 1    Strawberry-Watermelon Smoothie
# 2               Lebanese Tuna Salad
# 3              Fruity Broccoli Slaw
# 4           The Perfect Fruit Salad
# ..                              ...
# 575                Black Bean Chili
# 576                Tortellini Salad
# 577      Lemon-Glazed Chicken Wings
# 578             Carrot-Cake Oatmeal
# 579                 Pasta e Fagioli
#
# [580 rows x 1 columns]
